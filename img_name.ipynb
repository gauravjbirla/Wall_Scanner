# %%
import os

# %%
folder = "C:/Users/Rajat/Desktop/500-600/YellowLeafCurlVirus";

# %%
for cnt,i in enumerate(os.listdir(folder)):
  dst = f"YellowLeafCurlVirus_{str(cnt + 501)}.jpg"
  src =f"{folder}/{i}"
  dst =f"{folder}/{dst}"
  os.rename(src, dst)
  print(cnt,i)
# Out:
# 0 a020ee4e-9cae-443b-bb0a-d2ef47b7b9a3___YLCV_NREC 2362.JPG
# 1 a05153d6-05c7-4271-bd9e-60cbfbc8f8c7___UF.GRC_YLCV_Lab 01556.JPG
# 2 a0558a5c-b1d5-497f-8d55-f5f248d54a9f___YLCV_NREC 2686.JPG
# 3 a059d5b2-7c04-486f-9a92-7fd6e9199c3a___UF.GRC_YLCV_Lab 02139.JPG
# 4 a060ee22-57e7-4999-9ae8-e8a5ec56620c___YLCV_NREC 2727.JPG
# 5 a067f829-f243-4a0f-8172-41a072f51b83___YLCV_GCREC 2496.JPG
# 6 a084d0d8-ee33-4df4-94aa-7e651a0aa6c2___YLCV_GCREC 2771.JPG
# 7 a0913bb7-f133-470c-8fa7-8e77b7797206___UF.GRC_YLCV_Lab 02073.JPG
# 8 a09fa0f1-e128-44a0-9033-ce053b4971b6___UF.GRC_YLCV_Lab 01698.JPG
# 9 a12b102e-2fc0-4e25-bf1f-9b23392c8b2e___YLCV_GCREC 5279.JPG
# 10 a1310b30-d88f-4902-9d9a-71148318a68d___YLCV_GCREC 2059.JPG
# 11 a137af7e-9303-4def-8335-a2245781a60f___UF.GRC_YLCV_Lab 08439.JPG
# 12 a13f4aee-7d42-4194-92ba-48c9acedf592___UF.GRC_YLCV_Lab 02322.JPG
# 13 a13f6997-e1f9-49ac-8f8a-61bfbc0ba77f___YLCV_NREC 0194.JPG
# 14 a193e214-3a19-410d-8467-63eafff67aea___UF.GRC_YLCV_Lab 01457.JPG
# ...

# %%
for cnt,i in enumerate(os.listdir(folder)):
  print(cnt,i)
# Out:
# 0 Healthy_501.jpg
# 1 Healthy_502.jpg
# 2 Healthy_503.jpg
# 3 Healthy_504.jpg
# 4 Healthy_505.jpg
# 5 Healthy_506.jpg
# 6 Healthy_507.jpg
# 7 Healthy_508.jpg
# 8 Healthy_509.jpg
# 9 Healthy_510.jpg
# 10 Healthy_511.jpg
# 11 Healthy_512.jpg
# 12 Healthy_513.jpg
# 13 Healthy_514.jpg
# 14 Healthy_515.jpg
# 15 Healthy_516.jpg
# 16 Healthy_517.jpg
# 17 Healthy_518.jpg
# 18 Healthy_519.jpg
# 19 Healthy_520.jpg
# 20 Healthy_521.jpg
# 21 Healthy_522.jpg
# 22 Healthy_523.jpg
# 23 Healthy_524.jpg
# 24 Healthy_525.jpg
# 25 Healthy_526.jpg
# 26 Healthy_527.jpg
# 27 Healthy_528.jpg
# 28 Healthy_529.jpg
# 29 Healthy_530.jpg
# 30 Healthy_531.jpg
# 31 Healthy_532.jpg
# 32 Healthy_533.jpg
# 33 Healthy_534.jpg
# 34 Healthy_535.jpg
# 35 Healthy_536.jpg
# 36 Healthy_537.jpg
# 37 Healthy_538.jpg
# 38 Healthy_539.jpg
# 39 Healthy_540.jpg
# 40 Healthy_541.jpg
# 41 Healthy_542.jpg
# 42 Healthy_543.jpg
# 43 Healthy_544.jpg
# 44 Healthy_545.jpg
# 45 Healthy_546.jpg
# 46 Healthy_547.jpg
# 47 Healthy_548.jpg
# ...
